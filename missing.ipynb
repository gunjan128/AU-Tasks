# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("smartphones - smartphones.csv")

# %%
df.head()
# Out:
#                        model    price  rating  \
# 0              OnePlus 11 5G  ₹54,999    89.0
# 1  OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2      Samsung Galaxy A14 5G  ₹16,499    75.0
# 3       Motorola Moto G62 5G  ₹14,999    81.0
# 4         Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                        ram  \
# 0  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
# 1     Snapdragon 695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# 2        Exynos 1330, Octa Core, 2.4 GHz Processor    4 GB RAM, 64 GB inbuilt
# 3    Snapdragon  695, Octa Core, 2.2 GHz Processor   6 GB RAM, 128 GB inbuilt
# ...

# %%
df.isna().sum()
# Out:
# model          0
# price          0
# rating       141
# sim            0
# processor      0
# ram            0
# battery        0
# display        0
# camera         1
# card           7
# os            17
# dtype: int64

# %%
x=df.isna().sum()<10
x.values
# Out:
# array([ True,  True, False,  True,  True,  True,  True,  True,  True,
#         True, False])

# %%
col_to_remove=df.columns[x.values]
col_to_remove
# Out:
# Index(['model', 'price', 'sim', 'processor', 'ram', 'battery', 'display',
#        'camera', 'card'],
#       dtype='object')

# %%
df.dropna(subset=col_to_remove).isna().sum()
# Out:
# model          0
# price          0
# rating       134
# sim            0
# processor      0
# ram            0
# battery        0
# display        0
# camera         0
# card           0
# os            10
# dtype: int64

# %%
df.isna().sum()
# Out:
# model          0
# price          0
# rating       141
# sim            0
# processor      0
# ram            0
# battery        0
# display        0
# camera         1
# card           7
# os            17
# dtype: int64

# %%
df.isna().sum()
# Out:
# model          0
# price          0
# rating       141
# sim            0
# processor      0
# ram            0
# battery        0
# display        0
# camera         1
# card           7
# os            17
# dtype: int64

# %%
import missingno as msno

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
msno.heatmap(df)
# Out:
# <Axes: >

# %%
msno.bar(df)
# Out:
# <Axes: >

# %%
df[df["os"].isna()]
# Out:
#                              model    price  rating  \
# 473                   Nokia 110 4G   ₹1,762     NaN
# 532  Samsung Guru Music 2 Dual Sim   ₹1,949     NaN
# 573               Nokia 105 (2019)   ₹1,299     NaN
# 608              Namotel Achhe Din      ₹99     NaN
# 640                 Nokia 105 Plus   ₹1,299     NaN
# 645                Nokia 2760 Flip   ₹5,490     NaN
# 647              Motorola Moto A10   ₹1,339     NaN
# 657                  Zanco Tiny T1   ₹2,799     NaN
# 665                   itel it2163S     ₹958     NaN
# 699          Samsung Guru GT-E1215   ₹1,850     NaN
# 748                   Nokia 400 4G   ₹3,290     NaN
# 757                   Karbonn KU3i     ₹995     NaN
# 835                 Eunity U1 King     ₹599     NaN
# 857                    LG Folder 2  ₹11,999     NaN
# 881               Nokia 110 (2022)   ₹1,599     NaN
# 927             Samsung Guru E1200   ₹1,685     NaN
# 932                 Eunity U1 Livo     ₹649     NaN
#
# ...

# %%
df[df["card"].isna()]
# Out:
#                      model   price  rating         sim  \
# 573       Nokia 105 (2019)  ₹1,299     NaN  Single Sim
# 647      Motorola Moto A10  ₹1,339     NaN    Dual Sim
# 699  Samsung Guru GT-E1215  ₹1,850     NaN  Single Sim
# 835         Eunity U1 King    ₹599     NaN    Dual Sim
# 881       Nokia 110 (2022)  ₹1,599     NaN    Dual Sim
# 927     Samsung Guru E1200  ₹1,685     NaN  Single Sim
# 932         Eunity U1 Livo    ₹649     NaN    Dual Sim
#
#                   processor                               ram  \
# 573                 No Wifi            4 MB RAM, 4 MB inbuilt
# 647  4 MB RAM, 4 MB inbuilt                  1750 mAh Battery
# 699         800 mAh Battery  1.5 inches, 120 x 120 px Display
# 835      1.77 MHz Processor          32 MB RAM, 32 MB inbuilt
# 881                 No Wifi            4 MB RAM, 4 MB inbuilt
# 927                 No Wifi                   800 mAh Battery
# 932      1.77 MHz Processor          16 MB RAM, 16 MB inbuilt
#
# ...

# %%
df["os"].fillna("xy").isna().sum()
# Out:
# np.int64(0)

# %%
from sklearn.impute import SimpleImputer

# %%
most_frequent=SimpleImputer(strategy="most_frequent")

# %%
most_frequent.fit(df[["os"]])
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
most_frequent.statistics_
# Out:
# array(['Android v12'], dtype=object)

# %%
d=most_frequent.transform(df[["os"]])

# %%
d.sh
# Out:
# (1020, 1)
