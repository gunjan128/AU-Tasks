# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
tips=sns.load_dataset('tips')
iris=sns.load_dataset('iris')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.scatterplot(data=tips,x='smoker',y='total_bill')
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
sns.stripplot(data=tips,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=tips,x='day',y='total_bill',kind='strip',jitter=0.2,hue='sex')

# %%
# swarmplt
sns.swarmplot(data=tips,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips, x='day', y='total_bill' ,hue='day',dodge=False) # change the color the box
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips, x='day', y='total_bill',hue='day',dodge=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
## whihc day 
plt.axhline(tips['total_bill'].mean().color='red')# annont and apply arrow, axvline for virtical line
sns.boxplot(data=tips, x='day', y='total_bill')
# Out:
#   Cell In[57], line 2
#     plt.axhline(tips['total_bill'].mean().color='red')# annont and apply arrow, axvline for virtical line
#                 ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
plt.axhline(tips['total_bill'].mean(),color='red')
sns.boxplot(data=tips, x='day', y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
plt.axhline(19.78594262295082)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
import numpy as np
sns.barplot(data=tips,x='sex',y='total_bill',hue='smoker',estimator=np.min)  # upper side is the condidence
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>
